# %%
import os
from pathlib import Path

root_is_cwd = os.getcwd().endswith("fusionLearning")

if not root_is_cwd:
    os.chdir(Path().resolve().parent)
    print("Changed to root directory")
    root_is_cwd = True
else:
    print("Already in root directory")

print(os.getcwd())
# Out:
# Changed to root directory
# /home/cal390/fusionLearning/fusionLearning

# %%
from torch.utils.data import Dataset, DataLoader, random_split  # split technique up for discussion
import os
from PIL import Image
import numpy as np
import torch
from torchvision import transforms

# %%
from data.dataloaders import create_cityscapes_loaders_distributed #noqa
from config import DATA_DIR # noqa
from torch.distributed import init_process_group

init_process_group(backend='nccl')

train, val, test = create_cityscapes_loaders_distributed(DATA_DIR + "/cityscapes")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 5
#       2 from config import DATA_DIR # noqa
#       3 from torch.distributed import init_process_group
# ----> 5 init_process_group(backend='nccl')
#       7 train, val, test = create_cityscapes_loaders_distributed(DATA_DIR + "/cityscapes")
#
# File ~/fusionLearning/.venv/lib/python3.10/site-packages/torch/distributed/c10d_logger.py:83, in _exception_logger.<locals>.wrapper(*args, **kwargs)
#      80 @functools.wraps(func)
#      81 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> _T:
#      82     try:
# ---> 83         return func(*args, **kwargs)
#      84     except Exception as error:
#      85         msg_dict = _get_msg_dict(func.__name__, *args, **kwargs)
#
# ...
