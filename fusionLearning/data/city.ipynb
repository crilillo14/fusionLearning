# %%
import os
from pathlib import Path

root_is_cwd = os.getcwd().endswith("fusionLearning")

if not root_is_cwd:
    os.chdir(Path().resolve().parent)
    print("Changed to root directory")
    root_is_cwd = True
else:
    print("Already in root directory")

print(os.getcwd())
# Out:
# Already in root directory
# /Users/CristobalLillo_1/research/fusionLearning/fusionLearning

# %%
from torch.utils.data import Dataset, DataLoader, random_split  # split technique up for discussion
import os
from PIL import Image
import numpy as np
import torch
from torchvision import transforms

# %%
from data.dataloaders import create_cityscapes_loaders_distributed #noqa
from config import DATA_DIR # noqa

train, val, test = create_cityscapes_loaders_distributed(DATA_DIR + "/cityscapes")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 4
#       1 from data.dataloaders import create_cityscapes_loaders_distributed #noqa
#       2 from config import DATA_DIR # noqa
# ----> 4 train, val, test = create_cityscapes_loaders_distributed(DATA_DIR + "/cityscapes")
#
# File ~/research/fusionLearning/fusionLearning/data/dataloaders.py:276, in create_cityscapes_loaders_distributed(root, batch_size, gTransforms, pTransforms, num_workers)
#     266 def create_cityscapes_loaders_distributed(root: str,
#     267                                           batch_size: int = 8,
#     268                                           gTransforms=None,
#     269                                           pTransforms=None,
#     270                                           num_workers: int = 0):
#     271     """
#     272     Returns (train_loader, val_loader, test_loader).
#     273     Cityscapes test split has no GT labels; test_loader == val_loader.
#     274     Same return signature as create_train_val_test_loaders_distributed.
#     275     """
# --> 276     train_dataset = CityscapesDataset(root, 'train', gTransforms, pTransforms)
#     277     val_dataset   = CityscapesDataset(root, 'val')
#     278     # Cityscapes test has no ground-truth masks; use val as test
#
# File ~/research/fusionLearning/fusionLearning/data/dataloaders.py:236, in CityscapesDataset.__init__(self, root, split, gTransforms, pTransforms)
#     234 def __init__(self, root: str, split: str = 'train',
#     235              gTransforms=None, pTransforms=None):
# --> 236     self._inner = torchvision.datasets.Cityscapes(
#     237         root, split=split, mode='fine', target_type='semantic'
#     238     )
#     239     self.gTransforms = gTransforms
#     240     self.pTransforms = pTransforms
#
# File ~/research/fusionLearning/.venv/lib/python3.13/site-packages/torchvision/datasets/cityscapes.py:156, in Cityscapes.__init__(self, root, split, mode, target_type, transform, target_transform, transforms)
#     154         extract_archive(from_path=target_dir_zip, to_path=self.root)
#     155     else:
# --> 156         raise RuntimeError(
#     157             "Dataset not found or incomplete. Please make sure all required folders for the"
#     158             ' specified "split" and "mode" are inside the "root" directory'
#     159         )
#     161 for city in os.listdir(self.images_dir):
#     162     img_dir = os.path.join(self.images_dir, city)
#
# RuntimeError: Dataset not found or incomplete. Please make sure all required folders for the specified "split" and "mode" are inside the "root" directory
