# %% [markdown]
# # ViT

# %% [markdown]
# *Changing cwd to ```fusionLearning/```*

# %%
import os
from pathlib import Path

root_is_cwd = os.getcwd().endswith("fusionLearning")

if not root_is_cwd:
    os.chdir(Path().resolve().parent.parent)
    print("Changed to root directory")
    root_is_cwd = True
else:
    print("Already in root directory")

print(os.getcwd())

# %% [markdown]
# ### from https://github.com/jeonsworld/ViT-pytorch/blob/main/vit.py

# %%
MAXEPOCHS = 50
BATCHSIZE = 1
MOMENTUM = 0.99
LEARNING_RATE = 0.01
NUM_CLASSES = 2
